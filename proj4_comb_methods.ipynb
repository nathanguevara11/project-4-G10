# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import pandas as pd
import tensorflow as tf
import keras_tuner as kt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
import json
import requests
from config import api_key1
from pprint import pprint
import numpy as np
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine, text
from sqlalchemy.orm import Session
import ipywidgets as widgets
from IPython.display import display
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, ForeignKeyConstraint, PrimaryKeyConstraint, ForeignKey, Sequence, Date

# %%
url =  "https://api.sportradar.com/soccer/trial/v4/en/competitions/sr:competition:17/seasons/2024-2025/summaries.json?api_key=ag7HQReFOIevVetW1672RPc9iM642NkGMx0L5KHu"


# url = "https://api.sportradar.com/soccer/trial/v4/en/competitions/sr:competition:17/info.json?api_key=ag7HQReFOIevVetW1672RPc9iM642NkGMx0L5KHu"

headers = {"accept": "application/json"}

response = requests.get(url, headers=headers).json()

pprint(response)
# Out:
# {'generated_at': '2025-01-05T18:57:50+00:00', 'message': 'Invalid route.'}

# %%
base = "https://api.football-data.org/v4"

add_on = "/competitions/PL/matches"

url  = f"{base}{add_on}?dateFrom=2024-12-21&dateTo=2024-12-30"
headers = {
    "X-Auth-Token": api_key1
}

football_data = requests.get(url, headers = headers).json()

df = pd.json_normalize(football_data["matches"])
pprint(football_data["matches"][0])
#football_data["matches"][0]["awayTeam"]["name"]
df

# %%
# url = 'https://www.thesportsdb.com/api/v1/json/3/eventsseason.php'
# params = {
#     'id': '4328',  # Premier League league ID
#     's': '2024-2025'  # Season
# }

# response = requests.get(url, params=params)
# data = response.json()

# data_df = pd.json_normalize(data["events"])
# # Print or process the returned data
# # pprint(data["events"][0])
# # for column in data_df.columns:
# #     if "id" not in column:
# #         print(column)

# cols_dropped = []
# for col in data_df.columns: 
#     if ("id" in col) | ("Thumb" in col) | ("Banner" in col) | ("Map" in col) | ("Poster" in col) | ("Square" in col) | ("Badge" in col) | ("Fanart" in col)| ("Tweet" in col) | ("Postponed" in col)| ("Group" in col) | ("Locked" in col) | ("strLeague" in col)| ("strCity" in col) | ("Local" in col) | ("strOfficial" in col) | ("strDescription" in col)| ("strTimestamp" in col) | ("strResult" in col):
#         cols_dropped.append(col)

# d_df2 = data_df.drop(columns = cols_dropped, axis = 1)
# d_df2.columns

# d_df2
# Out:
#                         strEvent            strEventAlternate  \
# 0    Manchester United vs Fulham   Fulham @ Manchester United
# 1           Ipswich vs Liverpool          Liverpool @ Ipswich
# 2              Arsenal vs Wolves             Wolves @ Arsenal
# 3            Everton vs Brighton           Brighton @ Everton
# 4       Newcastle vs Southampton      Southampton @ Newcastle
# ..                           ...                          ...
# 95        Southampton vs Everton        Everton @ Southampton
# 96      Wolves vs Crystal Palace      Crystal Palace @ Wolves
# 97  Manchester United vs Chelsea  Chelsea @ Manchester United
# 98      Tottenham vs Aston Villa      Aston Villa @ Tottenham
# 99           Fulham vs Brentford           Brentford @ Fulham
#
#                                           strFilename strSport  strSeason  \
# 0   English Premier League 2024-08-16 Manchester U...   Soccer  2024-2025
# 1   English Premier League 2024-08-17 Ipswich vs L...   Soccer  2024-2025
# 2   English Premier League 2024-08-17 Arsenal vs W...   Soccer  2024-2025
# 3   English Premier League 2024-08-17 Everton vs B...   Soccer  2024-2025
# 4   English Premier League 2024-08-17 Newcastle vs...   Soccer  2024-2025
# ..                                                ...      ...        ...
# 95  English Premier League 2024-11-02 Southampton ...   Soccer  2024-2025
# 96  English Premier League 2024-11-02 Wolves vs Cr...   Soccer  2024-2025
# 97  English Premier League 2024-11-03 Manchester U...   Soccer  2024-2025
# 98  English Premier League 2024-11-03 Tottenham vs...   Soccer  2024-2025
# 99  English Premier League 2024-11-04 Fulham vs Br...   Soccer  2024-2025
#
#           strHomeTeam     strAwayTeam intHomeScore intRound intAwayScore  \
# 0   Manchester United          Fulham            1        1            0
# 1             Ipswich       Liverpool            0        1            2
# 2             Arsenal          Wolves            2        1            0
# 3             Everton        Brighton            0        1            3
# 4           Newcastle     Southampton            1        1            0
# ..                ...             ...          ...      ...          ...
# 95        Southampton         Everton            1       10            0
# 96             Wolves  Crystal Palace            2       10            2
# 97  Manchester United         Chelsea            1       10            1
# 98          Tottenham     Aston Villa            4       10            1
# 99             Fulham       Brentford            2       10            1
#
#    intSpectators   dateEvent   strTime intScore intScoreVotes  \
# 0           None  2024-08-16  19:00:00     None          None
# 1           None  2024-08-17  11:30:00     None          None
# 2           None  2024-08-17  14:00:00     None          None
# 3           None  2024-08-17  14:00:00     None          None
# 4           None  2024-08-17  14:00:00     None          None
# ..           ...         ...       ...      ...           ...
# 95          None  2024-11-02  15:00:00     None          None
# 96          None  2024-11-02  17:30:00     None          None
# 97          None  2024-11-03  16:30:00     None          None
# 98          None  2024-11-03  14:00:00     None          None
# 99          None  2024-11-04  20:00:00     None          None
#
#                      strVenue strCountry       strStatus
# 0                Old Trafford    England  Match Finished
# 1                Portman Road    England  Match Finished
# 2            Emirates Stadium    England  Match Finished
# 3               Goodison Park    England  Match Finished
# 4               St James Park    England  Match Finished
# ..                        ...        ...             ...
# 95                   St. Mary    England  Match Finished
# 96           Molineux Stadium    England  Match Finished
# 97               Old Trafford    England  Match Finished
# 98  Tottenham Hotspur Stadium    England  Match Finished
# 99             Craven Cottage    England  Match Finished
#
# [100 rows x 18 columns]

# %%
for index, row in d_df2.iterrows():
    if row["intHomeScore"] > row["intAwayScore"]:
        d_df2.at[index, "winner"] = row["strHomeTeam"]
    elif row["intHomeScore"] < row["intAwayScore"]:
        d_df2.at[index, "winner"] = row["strAwayTeam"]
    else:
        d_df2.at[index, "winner"] = "draw"

# %%
team_names = ["Arsenal",
"Aston Villa",
"Bournemouth",
"Brentford",
"Chelsea",
"Crystal Palace", 
"Everton",
"Fulham",
"Liverpool", 
"Luton Town", 
"Manchester City",
"Manchester United",
"Newcastle United", 
"Nottingham Forest",
"Sheffield United", 
"Tottenham Hotspur", 
"West Ham United", 
"Wolverhampton Wanderers", 
"Burnley",
"Brighton & Hove Albion"]

matches = []

# Loop through each row in the DataFrame
for index, row in d_df2.iterrows():
    # Check if the event string contains any of the team names
    for team in team_names:
        if team in row['strEvent']:
            # If a match is found, append the row to the matches list
            matches.append(row)

# Create a DataFrame from the matches list
teams_data = pd.DataFrame(matches)

# Now, to separate the data by team and ensure each team has their games listed,
# you can create a new DataFrame for each team and concatenate them.

# Initialize an empty list to hold DataFrames for each team
team_dfs = []

# Loop through each team name
for team in team_names:
    # Filter the teams_data for the current team
    team_df = teams_data[teams_data['strEvent'].str.contains(team)]
    # Add a new column for the team name
    team_df['Team'] = team
    # Append the filtered DataFrame to the list
    team_dfs.append(team_df)

# Concatenate all team DataFrames into one
final_teams_data = pd.concat(team_dfs, ignore_index=True)

# final_teams_data = final_teams_data.drop(columns = ["team"])

final_teams_data
# Out:
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\235588738.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['Team'] = team
#                                 strEvent                   strEventAlternate  \
# 0                      Arsenal vs Wolves                    Wolves @ Arsenal
# 1                 Aston Villa vs Arsenal               Arsenal @ Aston Villa
# 2                 Aston Villa vs Arsenal               Arsenal @ Aston Villa
# 3                    Arsenal vs Brighton                  Brighton @ Arsenal
# 4                   Tottenham vs Arsenal                 Arsenal @ Tottenham
# ..                                   ...                                 ...
# 181         Chelsea vs Nottingham Forest         Nottingham Forest @ Chelsea
# 182  Nottingham Forest vs Crystal Palace  Crystal Palace @ Nottingham Forest
# 183  Nottingham Forest vs Crystal Palace  Crystal Palace @ Nottingham Forest
# 184       Leicester vs Nottingham Forest       Nottingham Forest @ Leicester
# 185        Nottingham Forest vs West Ham        West Ham @ Nottingham Forest
#
#                                            strFilename strSport  strSeason  \
# 0    English Premier League 2024-08-17 Arsenal vs W...   Soccer  2024-2025
# 1    English Premier League 2024-08-24 Aston Villa ...   Soccer  2024-2025
# 2    English Premier League 2024-08-24 Aston Villa ...   Soccer  2024-2025
# 3    English Premier League 2024-08-31 Arsenal vs B...   Soccer  2024-2025
# 4    English Premier League 2024-09-15 Tottenham vs...   Soccer  2024-2025
# ..                                                 ...      ...        ...
# 181  English Premier League 2024-10-06 Chelsea vs N...   Soccer  2024-2025
# 182  English Premier League 2024-10-21 Nottingham F...   Soccer  2024-2025
# 183  English Premier League 2024-10-21 Nottingham F...   Soccer  2024-2025
# 184  English Premier League 2024-10-25 Leicester vs...   Soccer  2024-2025
# 185  English Premier League 2024-11-02 Nottingham F...   Soccer  2024-2025
#
#            strHomeTeam        strAwayTeam intHomeScore intRound intAwayScore  \
# 0              Arsenal             Wolves            2        1            0
# 1          Aston Villa            Arsenal            0        2            2
# 2          Aston Villa            Arsenal            0        2            2
# 3              Arsenal           Brighton            1        3            1
# 4            Tottenham            Arsenal            0        4            1
# ..                 ...                ...          ...      ...          ...
# 181            Chelsea  Nottingham Forest            1        7            1
# 182  Nottingham Forest     Crystal Palace            1        8            0
# 183  Nottingham Forest     Crystal Palace            1        8            0
# 184          Leicester  Nottingham Forest            1        9            3
# 185  Nottingham Forest           West Ham            3       10            0
#
#     intSpectators   dateEvent   strTime intScore intScoreVotes  \
# 0            None  2024-08-17  14:00:00     None          None
# 1            None  2024-08-24  16:30:00     None          None
# 2            None  2024-08-24  16:30:00     None          None
# 3            None  2024-08-31  11:30:00     None          None
# 4            None  2024-09-15  13:00:00       10             1
# ..            ...         ...       ...      ...           ...
# 181          None  2024-10-06  13:00:00     None          None
# 182          None  2024-10-21  19:00:00     None          None
# 183          None  2024-10-21  19:00:00     None          None
# 184          None  2024-10-25  19:00:00     None          None
# 185          None  2024-11-02  15:00:00     None          None
#
#                       strVenue strCountry       strStatus             winner  \
# 0             Emirates Stadium    England  Match Finished            Arsenal
# 1                   Villa Park    England  Match Finished            Arsenal
# 2                   Villa Park    England  Match Finished            Arsenal
# 3             Emirates Stadium    England  Match Finished               draw
# 4    Tottenham Hotspur Stadium    England  Match Finished            Arsenal
# ..                         ...        ...             ...                ...
# 181            Stamford Bridge    England  Match Finished               draw
# 182                City Ground    England  Match Finished  Nottingham Forest
# 183                City Ground    England  Match Finished  Nottingham Forest
# 184         King Power Stadium    England  Match Finished  Nottingham Forest
# 185                City Ground    England  Match Finished  Nottingham Forest
#
#                   Team
# 0              Arsenal
# 1              Arsenal
# 2              Arsenal
# 3              Arsenal
# 4              Arsenal
# ..                 ...
# 181  Nottingham Forest
# 182  Nottingham Forest
# 183  Nottingham Forest
# 184  Nottingham Forest
# 185  Nottingham Forest
#
# [186 rows x 20 columns]

# %%
for index, row in final_teams_data.iterrows(): 
    if row["Team"] == row["winner"]:
        final_teams_data.at[index, "result"] = 1
    elif (row["Team"] != row["winner"] and (row["winner"] != "draw")):
        final_teams_data.at[index, "result"] = -1
    elif row["winner"] == "draw": 
        final_teams_data.at[index, "result"] = 0
        
final_teams_data
# Out:
#                                 strEvent                   strEventAlternate  \
# 0                      Arsenal vs Wolves                    Wolves @ Arsenal
# 1                 Aston Villa vs Arsenal               Arsenal @ Aston Villa
# 2                 Aston Villa vs Arsenal               Arsenal @ Aston Villa
# 3                    Arsenal vs Brighton                  Brighton @ Arsenal
# 4                   Tottenham vs Arsenal                 Arsenal @ Tottenham
# ..                                   ...                                 ...
# 181         Chelsea vs Nottingham Forest         Nottingham Forest @ Chelsea
# 182  Nottingham Forest vs Crystal Palace  Crystal Palace @ Nottingham Forest
# 183  Nottingham Forest vs Crystal Palace  Crystal Palace @ Nottingham Forest
# 184       Leicester vs Nottingham Forest       Nottingham Forest @ Leicester
# 185        Nottingham Forest vs West Ham        West Ham @ Nottingham Forest
#
#                                            strFilename strSport  strSeason  \
# 0    English Premier League 2024-08-17 Arsenal vs W...   Soccer  2024-2025
# 1    English Premier League 2024-08-24 Aston Villa ...   Soccer  2024-2025
# 2    English Premier League 2024-08-24 Aston Villa ...   Soccer  2024-2025
# 3    English Premier League 2024-08-31 Arsenal vs B...   Soccer  2024-2025
# 4    English Premier League 2024-09-15 Tottenham vs...   Soccer  2024-2025
# ..                                                 ...      ...        ...
# 181  English Premier League 2024-10-06 Chelsea vs N...   Soccer  2024-2025
# 182  English Premier League 2024-10-21 Nottingham F...   Soccer  2024-2025
# 183  English Premier League 2024-10-21 Nottingham F...   Soccer  2024-2025
# 184  English Premier League 2024-10-25 Leicester vs...   Soccer  2024-2025
# 185  English Premier League 2024-11-02 Nottingham F...   Soccer  2024-2025
#
#            strHomeTeam        strAwayTeam intHomeScore intRound intAwayScore  \
# 0              Arsenal             Wolves            2        1            0
# 1          Aston Villa            Arsenal            0        2            2
# 2          Aston Villa            Arsenal            0        2            2
# 3              Arsenal           Brighton            1        3            1
# 4            Tottenham            Arsenal            0        4            1
# ..                 ...                ...          ...      ...          ...
# 181            Chelsea  Nottingham Forest            1        7            1
# 182  Nottingham Forest     Crystal Palace            1        8            0
# 183  Nottingham Forest     Crystal Palace            1        8            0
# 184          Leicester  Nottingham Forest            1        9            3
# 185  Nottingham Forest           West Ham            3       10            0
#
#      ...   dateEvent   strTime intScore intScoreVotes  \
# 0    ...  2024-08-17  14:00:00     None          None
# 1    ...  2024-08-24  16:30:00     None          None
# 2    ...  2024-08-24  16:30:00     None          None
# 3    ...  2024-08-31  11:30:00     None          None
# 4    ...  2024-09-15  13:00:00       10             1
# ..   ...         ...       ...      ...           ...
# 181  ...  2024-10-06  13:00:00     None          None
# 182  ...  2024-10-21  19:00:00     None          None
# 183  ...  2024-10-21  19:00:00     None          None
# 184  ...  2024-10-25  19:00:00     None          None
# 185  ...  2024-11-02  15:00:00     None          None
#
#                       strVenue strCountry       strStatus             winner  \
# 0             Emirates Stadium    England  Match Finished            Arsenal
# 1                   Villa Park    England  Match Finished            Arsenal
# 2                   Villa Park    England  Match Finished            Arsenal
# 3             Emirates Stadium    England  Match Finished               draw
# 4    Tottenham Hotspur Stadium    England  Match Finished            Arsenal
# ..                         ...        ...             ...                ...
# 181            Stamford Bridge    England  Match Finished               draw
# 182                City Ground    England  Match Finished  Nottingham Forest
# 183                City Ground    England  Match Finished  Nottingham Forest
# 184         King Power Stadium    England  Match Finished  Nottingham Forest
# 185                City Ground    England  Match Finished  Nottingham Forest
#
#                   Team result
# 0              Arsenal    1.0
# 1              Arsenal    1.0
# 2              Arsenal    1.0
# 3              Arsenal    0.0
# 4              Arsenal    1.0
# ..                 ...    ...
# 181  Nottingham Forest    0.0
# 182  Nottingham Forest    1.0
# 183  Nottingham Forest    1.0
# 184  Nottingham Forest    1.0
# 185  Nottingham Forest    1.0
#
# [186 rows x 21 columns]

# %%
final_teams_data["result"] = final_teams_data["result"].astype(int)

# final_teams_data = final_teams_data.drop(columns = ["intAwayScore", "intHomeScore"])

final_teams_data

#take off scores
# Out:
#                                 strEvent                   strEventAlternate  \
# 0                      Arsenal vs Wolves                    Wolves @ Arsenal
# 1                 Aston Villa vs Arsenal               Arsenal @ Aston Villa
# 2                 Aston Villa vs Arsenal               Arsenal @ Aston Villa
# 3                    Arsenal vs Brighton                  Brighton @ Arsenal
# 4                   Tottenham vs Arsenal                 Arsenal @ Tottenham
# ..                                   ...                                 ...
# 181         Chelsea vs Nottingham Forest         Nottingham Forest @ Chelsea
# 182  Nottingham Forest vs Crystal Palace  Crystal Palace @ Nottingham Forest
# 183  Nottingham Forest vs Crystal Palace  Crystal Palace @ Nottingham Forest
# 184       Leicester vs Nottingham Forest       Nottingham Forest @ Leicester
# 185        Nottingham Forest vs West Ham        West Ham @ Nottingham Forest
#
#                                            strFilename strSport  strSeason  \
# 0    English Premier League 2024-08-17 Arsenal vs W...   Soccer  2024-2025
# 1    English Premier League 2024-08-24 Aston Villa ...   Soccer  2024-2025
# 2    English Premier League 2024-08-24 Aston Villa ...   Soccer  2024-2025
# 3    English Premier League 2024-08-31 Arsenal vs B...   Soccer  2024-2025
# 4    English Premier League 2024-09-15 Tottenham vs...   Soccer  2024-2025
# ..                                                 ...      ...        ...
# 181  English Premier League 2024-10-06 Chelsea vs N...   Soccer  2024-2025
# 182  English Premier League 2024-10-21 Nottingham F...   Soccer  2024-2025
# 183  English Premier League 2024-10-21 Nottingham F...   Soccer  2024-2025
# 184  English Premier League 2024-10-25 Leicester vs...   Soccer  2024-2025
# 185  English Premier League 2024-11-02 Nottingham F...   Soccer  2024-2025
#
#            strHomeTeam        strAwayTeam intRound intSpectators   dateEvent  \
# 0              Arsenal             Wolves        1          None  2024-08-17
# 1          Aston Villa            Arsenal        2          None  2024-08-24
# 2          Aston Villa            Arsenal        2          None  2024-08-24
# 3              Arsenal           Brighton        3          None  2024-08-31
# 4            Tottenham            Arsenal        4          None  2024-09-15
# ..                 ...                ...      ...           ...         ...
# 181            Chelsea  Nottingham Forest        7          None  2024-10-06
# 182  Nottingham Forest     Crystal Palace        8          None  2024-10-21
# 183  Nottingham Forest     Crystal Palace        8          None  2024-10-21
# 184          Leicester  Nottingham Forest        9          None  2024-10-25
# 185  Nottingham Forest           West Ham       10          None  2024-11-02
#
#       strTime intScore intScoreVotes                   strVenue strCountry  \
# 0    14:00:00     None          None           Emirates Stadium    England
# 1    16:30:00     None          None                 Villa Park    England
# 2    16:30:00     None          None                 Villa Park    England
# 3    11:30:00     None          None           Emirates Stadium    England
# 4    13:00:00       10             1  Tottenham Hotspur Stadium    England
# ..        ...      ...           ...                        ...        ...
# 181  13:00:00     None          None            Stamford Bridge    England
# 182  19:00:00     None          None                City Ground    England
# 183  19:00:00     None          None                City Ground    England
# 184  19:00:00     None          None         King Power Stadium    England
# 185  15:00:00     None          None                City Ground    England
#
#           strStatus             winner               Team  result
# 0    Match Finished            Arsenal            Arsenal       1
# 1    Match Finished            Arsenal            Arsenal       1
# 2    Match Finished            Arsenal            Arsenal       1
# 3    Match Finished               draw            Arsenal       0
# 4    Match Finished            Arsenal            Arsenal       1
# ..              ...                ...                ...     ...
# 181  Match Finished               draw  Nottingham Forest       0
# 182  Match Finished  Nottingham Forest  Nottingham Forest       1
# 183  Match Finished  Nottingham Forest  Nottingham Forest       1
# 184  Match Finished  Nottingham Forest  Nottingham Forest       1
# 185  Match Finished  Nottingham Forest  Nottingham Forest       1
#
# [186 rows x 19 columns]

# %%
column_new = final_teams_data.columns

fixture_df = pd.DataFrame(None, columns = column_new)

fixture_df


#add fixtures
#iterrows
#do predictions based off row values 

#dropdown menu for future information 

# https://streamlit.io/
# Out:
# Empty DataFrame
# Columns: [strEvent, strEventAlternate, strFilename, strSport, strSeason, strHomeTeam, strAwayTeam, intRound, intSpectators, dateEvent, strTime, intScore, intScoreVotes, strVenue, strCountry, strStatus, winner, Team, result]
# Index: []

# %%
dummy = pd.get_dummies(final_teams_data, drop_first = False).astype(int)

# %%
len(dummy.columns)
# Out:
# 404

# %%
X = dummy.drop(columns = ["result"])

y= dummy["result"]

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42)

scaler =  StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)



# print(len(X.columns))

print(X.columns)
# Out:
# Index(['strEvent_Arsenal vs Brighton', 'strEvent_Arsenal vs Leicester',
#        'strEvent_Arsenal vs Liverpool', 'strEvent_Arsenal vs Southampton',
#        'strEvent_Arsenal vs Wolves', 'strEvent_Aston Villa vs Arsenal',
#        'strEvent_Aston Villa vs Bournemouth',
#        'strEvent_Aston Villa vs Everton',
#        'strEvent_Aston Villa vs Manchester United',
#        'strEvent_Aston Villa vs Wolves',
#        ...
#        'Team_Bournemouth', 'Team_Brentford', 'Team_Chelsea',
#        'Team_Crystal Palace', 'Team_Everton', 'Team_Fulham', 'Team_Liverpool',
#        'Team_Manchester City', 'Team_Manchester United',
#        'Team_Nottingham Forest'],
#       dtype='object', length=403)

# %%
#Random Forest Classification

rf_model = RandomForestClassifier(n_estimators=50, random_state=78, class_weight="balanced")
f_model = rf_model.fit(X_train_scaled, y_train)
predictions = rf_model.predict(X_test_scaled)

y2 = y_test.values.flatten()

p2 = predictions.flatten()

cm = confusion_matrix(y2, p2)
cm_df = pd.DataFrame(
    cm, index=["Actual 1", "Actual 0", "Actual -1"], columns=["Predicted 1", "Predicted 0", "Predictied -1"]
)

# # Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# print("Confusion Matrix")
# display(cm_df)
print(f"Accuracy Score : {acc_score}")
# print("Classification Report")
print(classification_report(y_test, predictions))

# importances = rf_model.feature_importances_
# # List the top 10 most important features
importances_sorted = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
importances_sorted[:10]

cm_df
# Out:
# Accuracy Score : 0.8297872340425532
#               precision    recall  f1-score   support
#
#           -1       0.57      0.80      0.67        10
#            0       1.00      1.00      1.00        17
#            1       0.88      0.70      0.78        20
#
#     accuracy                           0.83        47
#    macro avg       0.82      0.83      0.81        47
# weighted avg       0.86      0.83      0.83        47
#            Predicted 1  Predicted 0  Predictied -1
# Actual 1             8            0              2
# Actual 0             0           17              0
# Actual -1            6            0             14

# %%
# model created, feed fixtures in. Predict features

#list of future games 

# run model on game indiviually

# %%
# prediction_list = []

# list_games_left = [1,2,3,4,6]

# list_fixture = ["Everton", "Manunited", "tottenham", "Aston Villa "]

# predictions = rf_model.predict(list_fixture)

# for game in list_games_left:
#     for team in list_fixture:
#         predictions = rf_model.predict(list_fixture)
#         prediction_list.append()


#reset df after input

# fixture = []

# predictions = rf_model.predict(fixture)


# fixture_inputs = pd.DataFrame(None, columns= column_new)

# fixture_inputs["strEvent"] = input("What is the event?") 

# #...

# new = rf_model.predict(fixture_inputs)

# if new ==1:
#     print("WIN!")

# https://www.mathworks.com/videos/reinforcement-learning-part-1-what-is-reinforcement-learning-1551974943006.html?gclid=CjwKCAiA1eO7BhATEiwAm0Ee-FL8BYTrjDsks2d4XyVk74Wxwe9rXRq3eucN0RShTsSoErkY8Nfr-hoCXHwQAvD_BwE&ef_id=CjwKCAiA1eO7BhATEiwAm0Ee-FL8BYTrjDsks2d4XyVk74Wxwe9rXRq3eucN0RShTsSoErkY8Nfr-hoCXHwQAvD_BwE:G:s&s_kwcid=AL!8664!3!661408559891!e!!g!!reinforcement%20learning&s_eid=psn_76888626426&q=reinforcement+learning&gad_source=1

# %%
# #Random Forest Classification

# rf_model = RandomForestClassifier(n_estimators=50, random_state=78, class_weight="balanced")
# f_model = rf_model.fit(X_train_scaled, y_train)
# predictions = rf_model.predict(X_test_scaled)

# # # cm = confusion_matrix(y_test, predictions)
# # cm_df = pd.DataFrame(
# #     cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
# # )

# # # Calculating the accuracy score
# acc_score = accuracy_score(y_test, predictions)

# # print("Confusion Matrix")
# # display(cm_df)
# print(f"Accuracy Score : {acc_score}")
# # print("Classification Report")
# print(classification_report(y_test, predictions))

# # importances = rf_model.feature_importances_
# # # List the top 10 most important features
# importances_sorted = sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# importances_sorted[:10]

# %%
#Neural network 

nn = tf.keras.models.Sequential()

x_features = len(X_train.iloc[0])

nn.add(
    tf.keras.layers.Dense(units=30, input_dim=x_features, activation="relu")
)
nn.add(
    tf.keras.layers.Dense(units=20, activation="relu")
)
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))
# Out:
# c:\Users\librarypc\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
nn.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled,y_train,epochs=20)
# Out:
# Epoch 1/20
# c:\Users\librarypc\anaconda3\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.3686 - loss: 0.0000e+00
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3860 - loss: 0.0000e+00
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4317 - loss: 0.0000e+00
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4755 - loss: 0.0000e+00
# Epoch 5/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4145 - loss: 0.0000e+00
# Epoch 6/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4303 - loss: 0.0000e+00
# Epoch 7/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3993 - loss: 0.0000e+00
# Epoch 8/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4058 - loss: 0.0000e+00
# Epoch 9/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3610 - loss: 0.0000e+00
# Epoch 10/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3964 - loss: 0.0000e+00
# Epoch 11/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3957 - loss: 0.0000e+00
# Epoch 12/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2939 - loss: 0.0000e+00
# Epoch 13/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3082 - loss: 0.0000e+00
# Epoch 14/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3017 - loss: 0.0000e+00
# Epoch 15/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2975 - loss: 0.0000e+00
# Epoch 16/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2791 - loss: 0.0000e+00
# Epoch 17/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2558 - loss: 0.0000e+00
# Epoch 18/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2686 - loss: 0.0000e+00
# Epoch 19/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2270 - loss: 0.0000e+00
# Epoch 20/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2569 - loss: 0.0000e+00

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2/2 - 0s - 148ms/step - accuracy: 0.3617 - loss: 0.0000e+00
# Loss: 0.0, Accuracy: 0.3617021143436432

# %%
predicted = nn.predict(X_test)

# predicted = (predicted)

predictedb = (predicted > 0.5).astype(int)

print(f"Neural Network Accuracy: {accuracy_score(y_test, predictedb):.2f}")

predicted
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Neural Network Accuracy: 0.36
# array([[0.18899426],
#        [0.13948448],
#        [0.04361394],
#        [0.05917897],
#        [0.05917897],
#        [0.348501  ],
#        [0.33344436],
#        [0.1330262 ],
#        [0.02859321],
#        [0.27949232],
#        [0.0928824 ],
#        [0.06015665],
#        [0.10974868],
#        [0.10231733],
#        [0.2650028 ],
#        [0.348501  ],
#        [0.10964597],
#        [0.18592231],
#        [0.1041002 ],
#        [0.14442979],
#        [0.06015665],
#        [0.07002827],
#        [0.15085423],
#        [0.22727081],
#        [0.25004175],
#        [0.21428987],
#        [0.24031657],
#        [0.24037734],
#        [0.14442979],
#        [0.13948448],
#        [0.26128525],
#        [0.20361346],
#        [0.08168411],
#        [0.1753143 ],
#        [0.08486083],
#        [0.16165152],
#        [0.10161147],
#        [0.18592231],
#        [0.29619718],
#        [0.1041002 ],
#        [0.08267405],
#        [0.19877319],
#        [0.22125074],
#        [0.2335174 ],
#        [0.19511878],
#        [0.17570494],
#        [0.18062493]], dtype=float32)

# %%
import os
from dotenv import load_dotenv

load_dotenv() 
database_url = os.getenv("DATABASE_URL")
print(database_url)


engine = create_engine(database_url)

base = declarative_base()

class user_info(base): 
    __tablename__ = 'user_info'
    id = Column(Integer, primary_key=True, autoincrement=True, nullable=False)
    first_name = Column(String(250))
    last_name = Column(String(250))
    birthday = Column(Date)

    __table_args__ = (
        PrimaryKeyConstraint('id'), 
        {'extend_existing': True},
    )    
    
# base.metadata.create_all(engine)
# Out:
# postgresql://postgres:datacamp@localhost:5432/proj4orders
# C:\Users\librarypc\AppData\Local\Temp\ipykernel_29976\3170247372.py:11: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   base = declarative_base()

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind = engine)

session = Session()

# new = user_info(name = "Joe")

# session.add(new)
# session.commit()

# %%
class order(base): 
    __tablename__ = 'amount_add'
    
    order_id = Column(Integer, primary_key=True, autoincrement=True)
    user_id = Column(Integer)
    amount = Column(Float)
    team = Column(String(250))
    W_D_L = Column(String(250))

    __table_args__ = (
        ForeignKeyConstraint(['user_id'], ['user_info.id']),
        {'extend_existing':True},
    )
    
    
# base.metadata.create_all(engine)

# %%
# with engine.connect() as connection:
#     connection.execute(text("ALTER TABLE amount_add RENAME COLUMN reason_for TO team;"))
#     connection.commit()
#     print("Column name changed successfully!")

# %%
# try:
#     with engine.connect() as connection: 
#         connection.execute(text("ALTER TABLE amount_add ADD COLUMN Win_Draw_Loss VARCHAR(250);"))
#         print("success")
#         connection.commit()
# except Exception as e:
#     print(f"Error: {e}")

# %%
# new_order = order(user_id = 1 , amount= 1000)

# session.add(new_order)
# session.commit()

# %%
session.close()
