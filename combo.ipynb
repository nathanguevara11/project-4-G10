# %%
import pandas as pd

# Load your dataset 
nba2024_df = pd.read_csv('Resources/Seasons/nba_stats_2023-2024.csv')
nba2023_df = pd.read_csv('Resources/Seasons/nba_stats_2022-2023.csv')
nba2022_df = pd.read_csv('Resources/Seasons/nba_stats_2021-2022.csv')
nba2021_df = pd.read_csv('Resources/Seasons/nba_stats_2020-2021.csv')
nba2020_df = pd.read_csv('Resources/Seasons/nba_stats_2019-2020.csv')
nba2019_df = pd.read_csv('Resources/Seasons/nba_stats_2018-2019.csv')
nba2018_df = pd.read_csv('Resources/Seasons/nba_stats_2017-2018.csv')
nba2017_df = pd.read_csv('Resources/Seasons/nba_stats_2016-2017.csv')
nba2016_df = pd.read_csv('Resources/Seasons/nba_stats_2015-2016.csv')
nba2015_df = pd.read_csv('Resources/Seasons/nba_stats_2014-2015.csv')
nba2014_df = pd.read_csv('Resources/Seasons/nba_stats_2013-2014.csv')
nba2013_df = pd.read_csv('Resources/Seasons/nba_stats_2012-2013.csv')
nba2012_df = pd.read_csv('Resources/Seasons/nba_stats_2011-2012.csv')
nba2011_df = pd.read_csv('Resources/Seasons/nba_stats_2010-2011.csv')
nba2010_df = pd.read_csv('Resources/Seasons/nba_stats_2009-2010.csv')

# %%
# Name of the column to match
champ23 = 'Denver Nuggets*'

# Add the new column
nba2023_df['Champ'] = nba2023_df['Team'].apply(lambda x: 1 if x == champ23 else 0)

# View the result
nba2023_df

# Export to CSV
nba2023_df.to_csv('Resources/Seasons/nba_stats_2022-2023.csv', index=False)

# %%
# Name of the column to match
champ24 = 'Boston Celtics*'

# Add the new column
nba2024_df['Champ'] = nba2024_df['Team'].apply(lambda x: 1 if x == champ24 else 0)

# View the result
nba2024_df

# Export to CSV
nba2024_df.to_csv('Resources/Seasons/nba_stats_2023-2024.csv', index=False)

# %%
# Name of the column to match
champ22 = 'Golden State Warriors*'

# Add the new column
nba2022_df['Champ'] = nba2022_df['Team'].apply(lambda x: 1 if x == champ22 else 0)

# View the result
nba2022_df

# Export to CSV
nba2022_df.to_csv('Resources/Seasons/nba_stats_2021-2022.csv', index=False)

# %%
# Name of the column to match
champ21 = 'Milwaukee Bucks*'

# Add the new column
nba2021_df['Champ'] = nba2021_df['Team'].apply(lambda x: 1 if x == champ21 else 0)

# View the result
nba2021_df

# Export to CSV
nba2021_df.to_csv('Resources/Seasons/nba_stats_2020-2021.csv', index=False)

# %%
# Name of the column to match
champ20 = 'Los Angeles Lakers*'

# Add the new column
nba2020_df['Champ'] = nba2020_df['Team'].apply(lambda x: 1 if x == champ20 else 0)

# View the result
nba2020_df

# Export to CSV
nba2020_df.to_csv('Resources/Seasons/nba_stats_2019-2020.csv', index=False)

# %%
# Name of the column to match
champ19 = 'Toronto Raptors*'

# Add the new column
nba2019_df['Champ'] = nba2019_df['Team'].apply(lambda x: 1 if x == champ19 else 0)

# View the result
nba2019_df

# Export to CSV
nba2019_df.to_csv('Resources/Seasons/nba_stats_2018-2019.csv', index=False)

# %%
# Name of the column to match
champ18 = 'Golden State Warriors*'

# Add the new column
nba2018_df['Champ'] = nba2018_df['Team'].apply(lambda x: 1 if x == champ18 else 0)

# View the result
nba2018_df

# Export to CSV
nba2018_df.to_csv('Resources/Seasons/nba_stats_2017-2018.csv', index=False)

# %%
# Name of the column to match
champ17 = 'Golden State Warriors*'

# Add the new column
nba2017_df['Champ'] = nba2017_df['Team'].apply(lambda x: 1 if x == champ17 else 0)

# View the result
nba2017_df

# Export to CSV
nba2017_df.to_csv('Resources/Seasons/nba_stats_2016-2017.csv', index=False)
# Out:
#     Rk                     Team   Age   W   L  PW  PL    MOV   SOS    SRS  \
# 0    1   Golden State Warriors*  28.2  67  15  67  15  11.63 -0.28  11.35
# 1    2       San Antonio Spurs*  29.6  61  21  60  22   7.20 -0.06   7.13
# 2    3         Houston Rockets*  27.4  55  27  55  27   5.77  0.08   5.84
# 3    4         Toronto Raptors*  26.1  51  31  52  30   4.21 -0.56   3.65
# 4    5    Los Angeles Clippers*  30.0  51  31  52  30   4.29  0.13   4.42
# 5    6               Utah Jazz*  26.8  51  31  52  30   3.94  0.06   4.00
# 6    7     Cleveland Cavaliers*  29.2  51  31  49  33   3.18 -0.31   2.87
# 7    8          Boston Celtics*  25.9  53  29  48  34   2.63 -0.39   2.25
# 8    9      Washington Wizards*  26.0  49  33  46  36   1.80 -0.45   1.36
# 9   10               Miami Heat  26.5  41  41  44  38   1.06 -0.29   0.77
# 10  11   Oklahoma City Thunder*  24.7  47  35  43  39   0.76  0.39   1.14
# 11  12       Memphis Grizzlies*  29.5  43  39  42  40   0.49  0.47   0.96
# ...

# %%
# Name of the column to match
champ16 = 'Cleveland Cavaliers*'

# Add the new column
nba2016_df['Champ'] = nba2016_df['Team'].apply(lambda x: 1 if x == champ16 else 0)

# Export to CSV
nba2016_df.to_csv('Resources/Seasons/nba_stats_2015-2016.csv', index=False)

# View the result
nba2016_df
# Out:
#     Rk                     Team   Age   W   L  PW  PL    MOV   SOS    SRS  \
# 0    1       San Antonio Spurs*  30.3  67  15  67  15  10.63 -0.36  10.28
# 1    2   Golden State Warriors*  27.4  73   9  65  17  10.76 -0.38  10.38
# 2    3   Oklahoma City Thunder*  25.8  55  27  59  23   7.28 -0.19   7.09
# 3    4     Cleveland Cavaliers*  28.1  57  25  57  25   6.00 -0.55   5.45
# 4    5         Toronto Raptors*  26.3  56  26  53  29   4.50 -0.42   4.08
# 5    6    Los Angeles Clippers*  29.7  53  29  53  29   4.28 -0.15   4.13
# 6    7           Atlanta Hawks*  28.2  48  34  51  31   3.61 -0.12   3.49
# 7    8          Boston Celtics*  25.2  48  34  50  32   3.21 -0.37   2.84
# 8    9       Charlotte Hornets*  26.0  48  34  49  33   2.72 -0.36   2.36
# 9   10                Utah Jazz  24.2  40  42  46  36   1.79  0.05   1.84
# 10  11              Miami Heat*  28.4  48  34  46  36   1.65 -0.14   1.50
# 11  12          Indiana Pacers*  26.9  45  37  46  36   1.71 -0.09   1.62
# ...

# %%
# Name of the column to match
champ15 = 'Golden State Warriors*'

# Add the new column
nba2015_df['Champ'] = nba2015_df['Team'].apply(lambda x: 1 if x == champ15 else 0)

# Export to CSV
nba2015_df.to_csv('Resources/Seasons/nba_stats_2014-2015.csv', index=False)

# View the result
nba2015_df
# Out:
#     Rk                     Team   Age   W   L  PW  PL    MOV   SOS    SRS  \
# 0    1   Golden State Warriors*  26.6  67  15  65  17  10.10 -0.09  10.01
# 1    2    Los Angeles Clippers*  28.8  56  26  58  24   6.59  0.22   6.80
# 2    3       San Antonio Spurs*  29.8  55  27  58  24   6.20  0.14   6.34
# 3    4           Atlanta Hawks*  27.8  60  22  56  26   5.43 -0.68   4.75
# 4    5     Cleveland Cavaliers*  26.9  53  29  53  29   4.48 -0.40   4.08
# 5    6  Portland Trail Blazers*  27.0  51  31  53  29   4.23  0.18   4.41
# 6    7         Houston Rockets*  27.6  56  26  50  32   3.44  0.38   3.82
# 7    8       Memphis Grizzlies*  29.6  55  27  50  32   3.24  0.38   3.62
# 8    9         Toronto Raptors*  26.1  49  33  49  33   3.07 -0.62   2.45
# 9   10           Chicago Bulls*  28.8  50  32  50  32   3.00 -0.46   2.54
# 10  11        Dallas Mavericks*  29.9  50  32  49  33   2.90  0.46   3.36
# 11  12    Oklahoma City Thunder  25.4  45  37  47  35   2.18  0.28   2.47
# ...

# %%
# Name of the column to match
champ14 = 'San Antonio Spurs*'

# Add the new column
nba2014_df['Champ'] = nba2014_df['Team'].apply(lambda x: 1 if x == champ14 else 0)

# Export to CSV
nba2014_df.to_csv('Resources/Seasons/nba_stats_2013-2014.csv', index=False)

# View the result
nba2014_df
# Out:
#     Rk                     Team   Age   W   L  PW  PL    MOV   SOS    SRS  \
# 0    1       San Antonio Spurs*  28.9  62  20  61  21   7.72  0.28   8.00
# 1    2    Los Angeles Clippers*  28.1  57  25  59  23   6.98  0.30   7.27
# 2    3   Oklahoma City Thunder*  26.2  59  23  58  24   6.34  0.32   6.66
# 3    4              Miami Heat*  30.6  54  28  54  28   4.76 -0.61   4.15
# 4    5   Golden State Warriors*  26.3  51  31  54  28   4.80  0.34   5.15
# 5    6          Indiana Pacers*  27.2  56  26  54  28   4.40 -0.77   3.63
# 6    7         Houston Rockets*  25.4  54  28  53  29   4.56  0.50   5.06
# 7    8  Portland Trail Blazers*  25.8  54  28  52  30   3.99  0.45   4.44
# 8    9         Toronto Raptors*  25.6  48  34  50  32   3.24 -0.69   2.55
# 9   10             Phoenix Suns  26.2  48  34  48  34   2.63  0.39   3.02
# 10  11   Minnesota Timberwolves  26.3  40  42  48  34   2.67  0.43   3.10
# 11  12        Dallas Mavericks*  30.6  49  33  48  34   2.40  0.50   2.91
# ...

# %%
# Name of the column to match
champ13 = 'Miami Heat*'

# Add the new column
nba2013_df['Champ'] = nba2013_df['Team'].apply(lambda x: 1 if x == champ13 else 0)

# Export to CSV
nba2013_df.to_csv('Resources/Seasons/nba_stats_2012-2013.csv', index=False)

# View the result
nba2013_df
# Out:
#     Rk                    Team   Age   W   L  PW  PL   MOV   SOS   SRS  ...  \
# 0    1  Oklahoma City Thunder*  26.0  60  22  64  18  9.21 -0.06  9.15  ...
# 1    2             Miami Heat*  30.3  66  16  62  20  7.87 -0.84  7.03  ...
# 2    3   Los Angeles Clippers*  28.8  56  26  59  23  6.45 -0.02  6.43  ...
# 3    4      San Antonio Spurs*  28.6  58  24  58  24  6.40  0.27  6.67  ...
# 4    5         Denver Nuggets*  26.1  57  25  55  27  5.09  0.28  5.37  ...
# 5    6        New York Knicks*  30.2  54  28  53  29  4.23 -0.50  3.73  ...
# 6    7      Memphis Grizzlies*  27.0  56  26  54  28  4.15  0.18  4.32  ...
# 7    8         Indiana Pacers*  25.7  49  32  52  29  4.02 -0.69  3.34  ...
# 8    9        Houston Rockets*  24.4  45  37  50  32  3.48  0.22  3.69  ...
# 9   10          Brooklyn Nets*  28.6  49  33  46  36  1.78 -0.53  1.25  ...
# 10  11     Los Angeles Lakers*  30.7  45  37  44  38  1.16  0.32  1.48  ...
# ...

# %%
# Name of the column to match
champ12 = 'Miami Heat*'

# Add the new column
nba2012_df['Champ'] = nba2012_df['Team'].apply(lambda x: 1 if x == champ12 else 0)

# Export to CSV
nba2012_df.to_csv('Resources/Seasons/nba_stats_2011-2012.csv', index=False)

# View the result
nba2012_df
# Out:
#     Rk                    Team   Age   W   L  PW  PL    MOV   SOS    SRS  ...  \
# 0    1          Chicago Bulls*  27.1  50  16  51  15   8.18 -0.76   7.43  ...
# 1    2      San Antonio Spurs*  27.5  50  16  48  18   7.17  0.11   7.28  ...
# 2    3  Oklahoma City Thunder*  25.1  47  19  46  20   6.12  0.32   6.44  ...
# 3    4             Miami Heat*  28.3  46  20  47  19   5.98 -0.27   5.72  ...
# 4    5     Philadelphia 76ers*  24.9  35  31  43  23   4.24 -0.65   3.59  ...
# 5    6          Atlanta Hawks*  27.9  40  26  41  25   3.44 -0.77   2.67  ...
# 6    7         Indiana Pacers*  26.3  42  24  41  25   3.30 -0.71   2.60  ...
# 7    8        New York Knicks*  26.3  36  30  41  25   3.20 -0.81   2.39  ...
# 8    9         Denver Nuggets*  26.6  38  28  39  27   2.88  0.29   3.16  ...
# 9   10         Boston Celtics*  29.3  39  27  39  27   2.52 -0.26   2.26  ...
# 10  11   Los Angeles Clippers*  27.3  40  26  39  27   2.56  0.26   2.82  ...
# ...

# %%
# Name of the column to match
champ11 = 'Dallas Mavericks*'

# Add the new column
nba2011_df['Champ'] = nba2011_df['Team'].apply(lambda x: 1 if x == champ11 else 0)

# Export to CSV
nba2011_df.to_csv('Resources/Seasons/nba_stats_2010-2011.csv', index=False)

# View the result
nba2011_df
# Out:
#     Rk                     Team   Age   W   L  PW  PL   MOV   SOS   SRS  ...  \
# 0    1              Miami Heat*  29.0  58  24  61  21  7.46 -0.71  6.76  ...
# 1    2           Chicago Bulls*  26.4  62  20  61  21  7.32 -0.79  6.53  ...
# 2    3      Los Angeles Lakers*  30.2  57  25  58  24  6.11 -0.10  6.01  ...
# 3    4       San Antonio Spurs*  28.8  61  21  56  26  5.71  0.16  5.86  ...
# 4    5          Boston Celtics*  29.5  56  26  57  25  5.37 -0.54  4.83  ...
# 5    6           Orlando Magic*  27.6  52  30  56  26  5.46 -0.54  4.92  ...
# 6    7          Denver Nuggets*  27.3  50  32  54  28  4.76  0.05  4.81  ...
# 7    8        Dallas Mavericks*  30.9  57  25  53  29  4.23  0.18  4.41  ...
# 8    9   Oklahoma City Thunder*  23.7  55  27  51  31  3.79  0.02  3.81  ...
# 9   10       Memphis Grizzlies*  25.2  46  36  48  34  2.34  0.20  2.55  ...
# 10  11          Houston Rockets  26.5  43  39  47  35  2.18  0.19  2.37  ...
# ...

# %%
# Name of the column to match
champ10 = 'Los Angeles Lakers*'

# Add the new column
nba2010_df['Champ'] = nba2010_df['Team'].apply(lambda x: 1 if x == champ10 else 0)

# Export to CSV
nba2010_df.to_csv('Resources/Seasons/nba_stats_2009-2010.csv', index=False)

# View the result
nba2010_df
# Out:
#       Rk                     Team   Age     W     L  PW  PL   MOV   SOS   SRS  \
# 0    1.0           Orlando Magic*  27.9  59.0  23.0  61  21  7.49 -0.37  7.12
# 1    2.0     Cleveland Cavaliers*  28.0  61.0  21.0  59  23  6.52 -0.36  6.17
# 2    3.0               Utah Jazz*  25.6  53.0  29.0  55  27  5.34 -0.01  5.33
# 3    4.0       San Antonio Spurs*  28.7  50.0  32.0  55  27  5.09 -0.02  5.07
# 4    5.0           Atlanta Hawks*  26.5  53.0  29.0  54  28  4.66 -0.22  4.44
# 5    6.0            Phoenix Suns*  28.5  54.0  28.0  54  28  4.90 -0.23  4.67
# 6    7.0      Los Angeles Lakers*  28.4  57.0  25.0  54  28  4.72  0.06  4.78
# 7    8.0          Denver Nuggets*  27.7  53.0  29.0  52  30  4.09  0.06  4.15
# 8    9.0          Boston Celtics*  29.4  50.0  32.0  52  30  3.66 -0.29  3.37
# 9   10.0  Portland Trail Blazers*  26.6  50.0  32.0  51  31  3.30 -0.13  3.18
# 10  11.0   Oklahoma City Thunder*  23.2  50.0  32.0  51  31  3.49  0.06  3.55
# ...

# %%
import os

# Directory containing your CSV files
csv_folder = "Resources/Seasons"

# Get a list of all CSV files in the folder
csv_files = [os.path.join(csv_folder, f) for f in os.listdir(csv_folder) if f.endswith('.csv')]

# Read and combine all CSVs into one DataFrame
nba_df = pd.concat((pd.read_csv(file) for file in csv_files), ignore_index=True)

# Check the result
nba_df

# Export to CSV
nba_df.to_csv('Resources/nba.csv', index=False)
